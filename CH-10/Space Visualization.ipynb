# %%
import folium
from folium import Marker
from folium import plugins
from folium import GeoJson
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
df=pd.read_csv("Starbucks_Seoul.csv")

# 지역 구분을 위한 json 파일 불러오기
geo="datasets/Seoul_Gu.json" 

df.head()
# Out:
#        name                                   address gu_name   latitude  \
# 0      GS타워                   서울특별시 강남구 논현로 508 (역삼동)     강남구  37.501859
# 1  SSG마켓도곡R  서울특별시 강남구 언주로30길 57, 타워팰리스Ⅱ F 지하1층 (도곡동)     강남구  37.490298
# 2    W-Mall                  서울특별시 금천구 디지털로 188 (가산동)     금천구  37.477305
# 3     가든파이브             서울특별시 송파구 충민로 10 (문정동) 가든파이브툴     송파구  37.478232
# 4      가락본동                서울특별시 송파구 송파대로30길 13 (가락동)     송파구  37.494895
#
#     longitude
# 0  127.037278
# 1  127.054895
# 2  126.887691
# 3  127.119370
# 4  127.118785

# %%
# 기본 지도 시각화 (서울의 위도, 경도 입력)

m = folium.Map(location=[37.541, 126.986], zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f0b5c90a93996e4309e8a8ec0e533e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f0b5c90a93996e4309e8a8ec0e533e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f0b5c90a93996e4309e8a8ec0e533e1 = L.map(
#                 &quot;map_0f0b5c90a93996e4309e8a8ec0e533e1&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_108c646b432e82214c664559d1662ff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_108c646b432e82214c664559d1662ff9.addTo(map_0f0b5c90a93996e4309e8a8ec0e533e1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# 지도 형태 변경
m = folium.Map(location=[37.541, 126.986], tiles='Stamen Toner', zoom_start=12,
               attr='Map tiles by Stamen Design, under CC BY 3.0. Data by OpenStreetMap, under ODbL.')

# 원하는 좌표에 반경(radius) 표시 (남산)
folium.CircleMarker([37.5538, 126.9810], radius=50, 
                    popup='Laurelhurst Park', color='#3246cc', 
                    fill_color='#3246cc').add_to(m)

# 원하는 좌표에 포인트 표시 (남산)
folium.Marker([37.5538, 126.9810], popup='The Waterfront').add_to(m)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f2c0aedf1b303803415100f730ed50f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f2c0aedf1b303803415100f730ed50f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f2c0aedf1b303803415100f730ed50f = L.map(
#                 &quot;map_3f2c0aedf1b303803415100f730ed50f&quot;,
#                 {
#                     center: [37.541, 126.986],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9309002971b64717d181cdbeef68d2e = L.tileLayer(
#                 &quot;Stamen Toner&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by Stamen Design, under CC BY 3.0. Data by OpenStreetMap, under ODbL.&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9309002971b64717d181cdbeef68d2e.addTo(map_3f2c0aedf1b303803415100f730ed50f);
#
#
#             var circle_marker_4d22084b5dcfc9df027909d7c516dce9 = L.circleMarker(
#                 [37.5538, 126.981],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3246cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3246cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3f2c0aedf1b303803415100f730ed50f);
#
#
#         var popup_1fb9d81b08e20061708dcdfceb9a96d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c580faa54d87d1750f685cdcc18c6e95 = $(`&lt;div id=&quot;html_c580faa54d87d1750f685cdcc18c6e95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laurelhurst Park&lt;/div&gt;`)[0];
#                 popup_1fb9d81b08e20061708dcdfceb9a96d0.setContent(html_c580faa54d87d1750f685cdcc18c6e95);
#
#
#
#         circle_marker_4d22084b5dcfc9df027909d7c516dce9.bindPopup(popup_1fb9d81b08e20061708dcdfceb9a96d0)
#         ;
#
#
#
#
#             var marker_c617dd29b4a5298cba8ae0928209f158 = L.marker(
#                 [37.5538, 126.981],
#                 {}
#             ).addTo(map_3f2c0aedf1b303803415100f730ed50f);
#
#
#         var popup_de8ffbbe10ae260aaad81b24a19d38f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d79b7f7e036454ff9c806541c3a52498 = $(`&lt;div id=&quot;html_d79b7f7e036454ff9c806541c3a52498&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;The Waterfront&lt;/div&gt;`)[0];
#                 popup_de8ffbbe10ae260aaad81b24a19d38f0.setContent(html_d79b7f7e036454ff9c806541c3a52498);
#
#
#
#         marker_c617dd29b4a5298cba8ae0928209f158.bindPopup(popup_de8ffbbe10ae260aaad81b24a19d38f0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 서울 지도에 스타벅스 지점 수 시각화

m = folium.Map([37.541, 126.986], zoom_start=12 ,width="%100", height="%100")
locations = list(zip(df.latitude, df.longitude))
cluster = plugins.MarkerCluster(locations=locations,                     
               popups=df["name"].tolist())  
m.add_child(cluster)
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 서울 지도에 스타벅스 지점 수 시각화
# ----> 3 m = folium.Map([37.541, 126.986], zoom_start=12 ,width="%100", height="%100")
#       4 locations = list(zip(df.latitude, df.longitude))
#       5 cluster = plugins.MarkerCluster(locations=locations,
#       6                popups=df["name"].tolist())
#
# File c:\Users\pjung\OneDrive\문서\GitHub\Things-that-Data-Analysis-Must-Know\.venv\Lib\site-packages\folium\folium.py:283, in Map.__init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, font_size, **kwargs)
#     280 Figure().add_child(self)
#     282 # Map Size Parameters.
# --> 283 self.width = _parse_size(width)
#     284 self.height = _parse_size(height)
#     285 self.left = _parse_size(left)
#
# File c:\Users\pjung\OneDrive\문서\GitHub\Things-that-Data-Analysis-Must-Know\.venv\Lib\site-packages\branca\utilities.py:384, in _parse_size(value)
#     382         return float(match.group(1)), match.group(2)
#     383     else:
# --> 384         raise ValueError(
#     385             f"Cannot parse {value!r}, it should be a number followed by a unit.",
#     386         )
#     387 elif (
#     388     isinstance(value, tuple)
#     389     and isinstance(value[0], (int, float))
#     390     and isinstance(value[1], str)
#     391 ):
#     392     # value had been already parsed
#     393     return (float(value[0]), value[1])
#
# ValueError: Cannot parse '%100', it should be a number followed by a unit.
